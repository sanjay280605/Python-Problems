# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay280605/Python-Problems/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Resources

# %%
#Print Welcome
print('Welcome')
# Out:
# Welcome

# %%
#Print the given word
word = input("Enter a word: ")
print("The given word is:", word)
# Out:
# Enter a word: HELLOOO
# The given word is: HELLOOO

# %%
#Print the given message
message = input("Enter a message: ")
print("The given message is:", message)
# Out:
# Enter a message: Welcome to KCE
# The given message is: Welcome to KCE

# %%
#Print the given integer number.
num = int(input("Enter an integer number: "))
print("The given integer number is:", num)
# Out:
# Enter an integer number: -4
# The given integer number is: -4

# %%
#Print the given fractional number.
a= input("Enter a fraction: ")
print("The given fraction is:", a)
# Out:
# Enter a fraction: 4/9
# The given fraction is: 4/9

# %%
#Print given integer number in Hexadecimal format
num = int(input("Enter an integer number: "))
print("Hexadecimal format is:", hex(num))
# Out:
# Enter an integer number: 4910
# Hexadecimal format is: 0x132e

# %%
#Print given integer number in octal format.
num = int(input("Enter an integer number:"))
print("octal format is:", oct(num))
# Out:
# Enter an integer number:49
# octal format is: 0o61

# %%
#Print given hexadecimal number in integer format
hex_num = input("Enter a hexadecimal number: ")
print("Integer format is:", int(hex_num, 16))
# Out:
# Enter a hexadecimal number: 0x31
# Integer format is: 49

# %%
#Print given octal number in integer format
oct_code = input("Enter an octal number:")
print("Integer format is:", int(oct_code, 8))
# Out:
# Enter an octal number:0o61
# Integer format is: 49

# %%
ch = input("Enter character: ")
print(ord(ch))
